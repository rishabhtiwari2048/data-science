# %% [markdown]
# ## Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### You can create a series object with a list or numpy array or a dictionary

# %% [markdown]
# ### Series with List

# %%
my_list = [i for i in range(0,5)]
my_index =[i for i in 'risha']

# %%
my_list, my_index
# Out:
# ([0, 1, 2, 3, 4], ['r', 'i', 's', 'h', 'a'])

# %%
pd.Series(data=my_list, index=my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int64

# %%
pd.Series(my_list)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
pd.Series(my_list,my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int64

# %% [markdown]
# ### Series with NumPy array

# %%
array = np.arange(0,5)

# %%
array, my_index
# Out:
# (array([0, 1, 2, 3, 4]), ['r', 'i', 's', 'h', 'a'])

# %%
pd.Series(data = array)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32

# %%
pd.Series(data = array, index = my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int32

# %% [markdown]
# ### Series with Dictionary

# %%
dict1 = {'one':1,'two':2,'three':3,'four':4}

# %%
dict1
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
ser1 = pd.Series(dict1)
ser1
# Out:
# one      1
# two      2
# three    3
# four     4
# dtype: int64

# %% [markdown]
# ## Series can hold wide variety of datatypes

# %%
## strings
list1 = ['a','b','c','d']
list2 = [1,2,3,4]
ser2 = pd.Series(data= list1 , index= list2)
ser2
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
## holding functions
list1 = [sum,min,max,type,range]
list2 = ['sum','min','max','type','range']
ser3 = pd.Series(data=list1, index=list2)
ser3
# Out:
# sum      <built-in function sum>
# min      <built-in function min>
# max      <built-in function max>
# type              <class 'type'>
# range            <class 'range'>
# dtype: object

# %% [markdown]
# ## Grabbing data from series

# %%
ser2[1]
# Out:
# 'a'

# %%
dict1 = {'Mumbai':100,'Delhi':200,'Kolkata':300,'Chennai':400,'Bengaluru':500}
ser1 = pd.Series(dict1)
ser2 = pd.Series({'Mumbai':100,'Kolkata':300,'Chennai':400,'Bengaluru':500})
ser3 = pd.Series({'Mumbai':100,'Delhi':200,'Kolkata':300,'Bengaluru':500})

# %%
ser1['Mumbai']
# Out:
# 100

# %%
ser1
# Out:
# Mumbai       100
# Delhi        200
# Kolkata      300
# Chennai      400
# Bengaluru    500
# dtype: int64

# %%
ser2
# Out:
# Mumbai       100
# Kolkata      300
# Chennai      400
# Bengaluru    500
# dtype: int64

# %%
ser3
# Out:
# Mumbai       100
# Delhi        200
# Kolkata      300
# Bengaluru    500
# dtype: int64

# %% [markdown]
# ### Basic operations on Series

# %%
ser1 +  ser2
# Out:
# Bengaluru    1000.0
# Chennai       800.0
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %%
ser2 + ser3
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %% [markdown]
# ## Basic functions and attributes

# %%
ser = ser2 + ser3
ser
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %%
ser.isnull()
# Out:
# Bengaluru    False
# Chennai       True
# Delhi         True
# Kolkata      False
# Mumbai       False
# dtype: bool

# %%
ser.notnull()
# Out:
# Bengaluru     True
# Chennai      False
# Delhi        False
# Kolkata       True
# Mumbai        True
# dtype: bool

# %%
ser.size
# Out:
# 5

# %%
ser.axes
# Out:
# [Index(['Bengaluru', 'Chennai', 'Delhi', 'Kolkata', 'Mumbai'], dtype='object')]

# %%
ser.values
# Out:
# array([1000.,   nan,   nan,  600.,  200.])

# %%
ser.empty
# Out:
# False

# %%
ser.max()
# Out:
# 1000.0

# %%
ser.min()
# Out:
# 200.0

# %%
ser.std()
# Out:
# 400.0

# %%
ser.var()
# Out:
# 160000.0

# %%
ser.sum()
# Out:
# 1800.0

# %%
ser.mean()
# Out:
# 600.0

# %%
ser.head(2)
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# dtype: float64

# %%
ser.tail(3)
# Out:
# Delhi        NaN
# Kolkata    600.0
# Mumbai     200.0
# dtype: float64

# %% [markdown]
# ## Dataframes

# %% [markdown]
# ### Creating a dataframe

# %%
rows = 'India Australia Japan US Russia England France Germany Bhutan Fiji'.split()
cols = 'c1 c2 c3 c4 c5 c6 c7 c8 c9 c10'.split()
data = np.random.randint(0,100,100).reshape(10,10)

# %%
rows
# Out:
# ['India',
#  'Australia',
#  'Japan',
#  'US',
#  'Russia',
#  'England',
#  'France',
#  'Germany',
#  'Bhutan',
#  'Fiji']

# %%
cols
# Out:
# ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10']

# %%
data
# Out:
# array([[96, 97, 99, 94,  3,  3, 90, 84, 30, 30],
#        [22, 12, 98,  9, 30, 47,  0, 59, 59, 96],
#        [34, 77, 24, 93, 59, 64, 56, 96, 91, 62],
#        [12,  0, 44, 28,  9, 41, 69, 72, 30, 27],
#        [ 5, 88, 58, 83, 80, 29, 31, 89, 28, 73],
#        [ 4, 13,  5, 63, 53, 32, 89, 55, 78, 86],
#        [12, 38, 59, 11,  8, 57, 91, 74, 44, 29],
#        [ 5, 10, 63, 69, 31, 72, 33, 46, 33, 93],
#        [82, 19, 56, 77, 22, 40, 31, 22, 58, 64],
#        [37, 52, 54, 43, 31, 44, 80, 29, 13, 48]])

# %%
df = pd.DataFrame(data=data, index=rows, columns=cols)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      96  97  99  94   3   3  90  84  30   30
# Australia  22  12  98   9  30  47   0  59  59   96
# Japan      34  77  24  93  59  64  56  96  91   62
# US         12   0  44  28   9  41  69  72  30   27
# Russia      5  88  58  83  80  29  31  89  28   73
# England     4  13   5  63  53  32  89  55  78   86
# France     12  38  59  11   8  57  91  74  44   29
# Germany     5  10  63  69  31  72  33  46  33   93
# Bhutan     82  19  56  77  22  40  31  22  58   64
# Fiji       37  52  54  43  31  44  80  29  13   48

# %% [markdown]
#  ## Getting data out of DataFrames

# %% [markdown]
# ### Selecting columns

# %%
df['c1']
# Out:
# India        96
# Australia    22
# Japan        34
# US           12
# Russia        5
# England       4
# France       12
# Germany       5
# Bhutan       82
# Fiji         37
# Name: c1, dtype: int32

# %%
df[['c1','c2']]
# Out:
#            c1  c2
# India      96  97
# Australia  22  12
# Japan      34  77
# US         12   0
# Russia      5  88
# England     4  13
# France     12  38
# Germany     5  10
# Bhutan     82  19
# Fiji       37  52

# %% [markdown]
# ### Selecting rows

# %%
df.loc['India']
# Out:
# c1     96
# c2     97
# c3     99
# c4     94
# c5      3
# c6      3
# c7     90
# c8     84
# c9     30
# c10    30
# Name: India, dtype: int32

# %%
df.iloc[3]
# Out:
# c1     12
# c2      0
# c3     44
# c4     28
# c5      9
# c6     41
# c7     69
# c8     72
# c9     30
# c10    27
# Name: US, dtype: int32

# %%
df.loc[['India','England','Russia']]
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India    96  97  99  94   3   3  90  84  30   30
# England   4  13   5  63  53  32  89  55  78   86
# Russia    5  88  58  83  80  29  31  89  28   73

# %% [markdown]
# ### Selecting subset of a dataframe

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      96  97  99  94   3   3  90  84  30   30
# Australia  22  12  98   9  30  47   0  59  59   96
# Japan      34  77  24  93  59  64  56  96  91   62
# US         12   0  44  28   9  41  69  72  30   27
# Russia      5  88  58  83  80  29  31  89  28   73
# England     4  13   5  63  53  32  89  55  78   86
# France     12  38  59  11   8  57  91  74  44   29
# Germany     5  10  63  69  31  72  33  46  33   93
# Bhutan     82  19  56  77  22  40  31  22  58   64
# Fiji       37  52  54  43  31  44  80  29  13   48

# %%
df.loc[['Japan','US','Russia'],['c5','c6','c7']]
# Out:
#         c5  c6  c7
# Japan   59  64  56
# US       9  41  69
# Russia  80  29  31

# %% [markdown]
# ### Adding a new column

# %%
df['c11'] = np.arange(0,10)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      96  97  99  94   3   3  90  84  30   30    0
# Australia  22  12  98   9  30  47   0  59  59   96    1
# Japan      34  77  24  93  59  64  56  96  91   62    2
# US         12   0  44  28   9  41  69  72  30   27    3
# Russia      5  88  58  83  80  29  31  89  28   73    4
# England     4  13   5  63  53  32  89  55  78   86    5
# France     12  38  59  11   8  57  91  74  44   29    6
# Germany     5  10  63  69  31  72  33  46  33   93    7
# Bhutan     82  19  56  77  22  40  31  22  58   64    8
# Fiji       37  52  54  43  31  44  80  29  13   48    9

# %% [markdown]
# ### Adding a new row

# %%
df.loc['Poland'] = np.random.randint(0,100,11)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      96  97  99  94   3   3  90  84  30   30    0
# Australia  22  12  98   9  30  47   0  59  59   96    1
# Japan      34  77  24  93  59  64  56  96  91   62    2
# US         12   0  44  28   9  41  69  72  30   27    3
# Russia      5  88  58  83  80  29  31  89  28   73    4
# England     4  13   5  63  53  32  89  55  78   86    5
# France     12  38  59  11   8  57  91  74  44   29    6
# Germany     5  10  63  69  31  72  33  46  33   93    7
# Bhutan     82  19  56  77  22  40  31  22  58   64    8
# Fiji       37  52  54  43  31  44  80  29  13   48    9
# Poland     69  75  64  74  52  25  57  11  59   60   52

# %% [markdown]
# ### Dropping a column

# %%
df.drop('c11', axis=1)
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      96  97  99  94   3   3  90  84  30   30
# Australia  22  12  98   9  30  47   0  59  59   96
# Japan      34  77  24  93  59  64  56  96  91   62
# US         12   0  44  28   9  41  69  72  30   27
# Russia      5  88  58  83  80  29  31  89  28   73
# England     4  13   5  63  53  32  89  55  78   86
# France     12  38  59  11   8  57  91  74  44   29
# Germany     5  10  63  69  31  72  33  46  33   93
# Bhutan     82  19  56  77  22  40  31  22  58   64
# Fiji       37  52  54  43  31  44  80  29  13   48
# Poland     69  75  64  74  52  25  57  11  59   60

# %% [markdown]
# ### Dropping a row

# %%
df.drop('Poland',axis=0)
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      96  97  99  94   3   3  90  84  30   30    0
# Australia  22  12  98   9  30  47   0  59  59   96    1
# Japan      34  77  24  93  59  64  56  96  91   62    2
# US         12   0  44  28   9  41  69  72  30   27    3
# Russia      5  88  58  83  80  29  31  89  28   73    4
# England     4  13   5  63  53  32  89  55  78   86    5
# France     12  38  59  11   8  57  91  74  44   29    6
# Germany     5  10  63  69  31  72  33  46  33   93    7
# Bhutan     82  19  56  77  22  40  31  22  58   64    8
# Fiji       37  52  54  43  31  44  80  29  13   48    9

# %% [markdown]
# ## Conditional Selection

# %%
df >=50
# Out:
#               c1     c2     c3     c4     c5     c6     c7     c8     c9  \
# India       True   True   True   True  False  False   True   True  False
# Australia  False  False   True  False  False  False  False   True   True
# Japan      False   True  False   True   True   True   True   True   True
# US         False  False  False  False  False  False   True   True  False
# Russia     False   True   True   True   True  False  False   True  False
# England    False  False  False   True   True  False   True   True   True
# France     False  False   True  False  False   True   True   True  False
# Germany    False  False   True   True  False   True  False  False  False
# Bhutan      True  False   True   True  False  False  False  False   True
# Fiji       False   True   True  False  False  False   True  False  False
# Poland      True   True   True   True   True  False   True  False   True
#
#              c10    c11
# India      False  False
# Australia   True  False
# Japan       True  False
# US         False  False
# Russia      True  False
# England     True  False
# France     False  False
# Germany     True  False
# Bhutan      True  False
# Fiji       False  False
# Poland      True   True

# %%
df[df>=50]
# Out:
#              c1    c2    c3    c4    c5    c6    c7    c8    c9   c10   c11
# India      96.0  97.0  99.0  94.0   NaN   NaN  90.0  84.0   NaN   NaN   NaN
# Australia   NaN   NaN  98.0   NaN   NaN   NaN   NaN  59.0  59.0  96.0   NaN
# Japan       NaN  77.0   NaN  93.0  59.0  64.0  56.0  96.0  91.0  62.0   NaN
# US          NaN   NaN   NaN   NaN   NaN   NaN  69.0  72.0   NaN   NaN   NaN
# Russia      NaN  88.0  58.0  83.0  80.0   NaN   NaN  89.0   NaN  73.0   NaN
# England     NaN   NaN   NaN  63.0  53.0   NaN  89.0  55.0  78.0  86.0   NaN
# France      NaN   NaN  59.0   NaN   NaN  57.0  91.0  74.0   NaN   NaN   NaN
# Germany     NaN   NaN  63.0  69.0   NaN  72.0   NaN   NaN   NaN  93.0   NaN
# Bhutan     82.0   NaN  56.0  77.0   NaN   NaN   NaN   NaN  58.0  64.0   NaN
# Fiji        NaN  52.0  54.0   NaN   NaN   NaN  80.0   NaN   NaN   NaN   NaN
# Poland     69.0  75.0  64.0  74.0  52.0   NaN  57.0   NaN  59.0  60.0  52.0

# %%
df[df['c1']>=50]
# Out:
#         c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India   96  97  99  94   3   3  90  84  30   30    0
# Bhutan  82  19  56  77  22  40  31  22  58   64    8
# Poland  69  75  64  74  52  25  57  11  59   60   52

# %%
df[df['c1']>=50].loc[['India','Bhutan']]
# Out:
#         c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India   96  97  99  94   3   3  90  84  30   30    0
# Bhutan  82  19  56  77  22  40  31  22  58   64    8

# %%
 df[(df>50) | (df%20==0)]
# Out:
#              c1    c2    c3    c4    c5    c6    c7    c8    c9   c10   c11
# India      96.0  97.0  99.0  94.0   NaN   NaN  90.0  84.0   NaN   NaN   0.0
# Australia   NaN   NaN  98.0   NaN   NaN   NaN   0.0  59.0  59.0  96.0   NaN
# Japan       NaN  77.0   NaN  93.0  59.0  64.0  56.0  96.0  91.0  62.0   NaN
# US          NaN   0.0   NaN   NaN   NaN   NaN  69.0  72.0   NaN   NaN   NaN
# Russia      NaN  88.0  58.0  83.0  80.0   NaN   NaN  89.0   NaN  73.0   NaN
# England     NaN   NaN   NaN  63.0  53.0   NaN  89.0  55.0  78.0  86.0   NaN
# France      NaN   NaN  59.0   NaN   NaN  57.0  91.0  74.0   NaN   NaN   NaN
# Germany     NaN   NaN  63.0  69.0   NaN  72.0   NaN   NaN   NaN  93.0   NaN
# Bhutan     82.0   NaN  56.0  77.0   NaN  40.0   NaN   NaN  58.0  64.0   NaN
# Fiji        NaN  52.0  54.0   NaN   NaN   NaN  80.0   NaN   NaN   NaN   NaN
# Poland     69.0  75.0  64.0  74.0  52.0   NaN  57.0   NaN  59.0  60.0  52.0

# %% [markdown]
# ### Useful Methods

# %%
### RESET INDEX
df.reset_index()
# Out:
#         index  c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# 0       India  96  97  99  94   3   3  90  84  30   30    0
# 1   Australia  22  12  98   9  30  47   0  59  59   96    1
# 2       Japan  34  77  24  93  59  64  56  96  91   62    2
# 3          US  12   0  44  28   9  41  69  72  30   27    3
# 4      Russia   5  88  58  83  80  29  31  89  28   73    4
# 5     England   4  13   5  63  53  32  89  55  78   86    5
# 6      France  12  38  59  11   8  57  91  74  44   29    6
# 7     Germany   5  10  63  69  31  72  33  46  33   93    7
# 8      Bhutan  82  19  56  77  22  40  31  22  58   64    8
# 9        Fiji  37  52  54  43  31  44  80  29  13   48    9
# 10     Poland  69  75  64  74  52  25  57  11  59   60   52

# %%
df['new_ind'] = 'a b c d e f g h i j k'.split()

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11 new_ind
# India      96  97  99  94   3   3  90  84  30   30    0       a
# Australia  22  12  98   9  30  47   0  59  59   96    1       b
# Japan      34  77  24  93  59  64  56  96  91   62    2       c
# US         12   0  44  28   9  41  69  72  30   27    3       d
# Russia      5  88  58  83  80  29  31  89  28   73    4       e
# England     4  13   5  63  53  32  89  55  78   86    5       f
# France     12  38  59  11   8  57  91  74  44   29    6       g
# Germany     5  10  63  69  31  72  33  46  33   93    7       h
# Bhutan     82  19  56  77  22  40  31  22  58   64    8       i
# Fiji       37  52  54  43  31  44  80  29  13   48    9       j
# Poland     69  75  64  74  52  25  57  11  59   60   52       k

# %%
df.set_index('new_ind',inplace=True)

# %%
df
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# a        96  97  99  94   3   3  90  84  30   30    0
# b        22  12  98   9  30  47   0  59  59   96    1
# c        34  77  24  93  59  64  56  96  91   62    2
# d        12   0  44  28   9  41  69  72  30   27    3
# e         5  88  58  83  80  29  31  89  28   73    4
# f         4  13   5  63  53  32  89  55  78   86    5
# g        12  38  59  11   8  57  91  74  44   29    6
# h         5  10  63  69  31  72  33  46  33   93    7
# i        82  19  56  77  22  40  31  22  58   64    8
# j        37  52  54  43  31  44  80  29  13   48    9
# k        69  75  64  74  52  25  57  11  59   60   52

# %%
df.head()
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# a        96  97  99  94   3   3  90  84  30   30    0
# b        22  12  98   9  30  47   0  59  59   96    1
# c        34  77  24  93  59  64  56  96  91   62    2
# d        12   0  44  28   9  41  69  72  30   27    3
# e         5  88  58  83  80  29  31  89  28   73    4

# %%
df.tail()
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# g        12  38  59  11   8  57  91  74  44   29    6
# h         5  10  63  69  31  72  33  46  33   93    7
# i        82  19  56  77  22  40  31  22  58   64    8
# j        37  52  54  43  31  44  80  29  13   48    9
# k        69  75  64  74  52  25  57  11  59   60   52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, a to k
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      11 non-null     int32
#  1   c2      11 non-null     int32
#  2   c3      11 non-null     int32
#  3   c4      11 non-null     int32
#  4   c5      11 non-null     int32
#  5   c6      11 non-null     int32
#  6   c7      11 non-null     int32
#  7   c8      11 non-null     int32
#  8   c9      11 non-null     int32
#  9   c10     11 non-null     int32
#  10  c11     11 non-null     int32
# dtypes: int32(11)
# memory usage: 572.0+ bytes

# %%
df.describe()
# Out:
#               c1         c2         c3         c4         c5         c6  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   34.363636  43.727273  56.727273  58.545455  34.363636  41.272727
# std    33.278440  35.491100  27.397412  31.049521  24.216824  19.277401
# min     4.000000   0.000000   5.000000   9.000000   3.000000   3.000000
# 25%     8.500000  12.500000  49.000000  35.500000  15.500000  30.500000
# 50%    22.000000  38.000000  58.000000  69.000000  31.000000  41.000000
# 75%    53.000000  76.000000  63.500000  80.000000  52.500000  52.000000
# max    96.000000  97.000000  99.000000  94.000000  80.000000  72.000000
#
#               c7         c8         c9        c10        c11
# count  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   57.000000  57.909091  47.545455  60.727273   8.818182
# std    30.199338  28.342387  23.670081  25.175746  14.606972
# min     0.000000  11.000000  13.000000  27.000000   0.000000
# 25%    32.000000  37.500000  30.000000  39.000000   2.500000
# 50%    57.000000  59.000000  44.000000  62.000000   5.000000
# 75%    84.500000  79.000000  59.000000  79.500000   7.500000
# max    91.000000  96.000000  91.000000  96.000000  52.000000

# %% [markdown]
# ## Hierarichal Indexing

# %%
index = [['Asia','Asia','Asia','Europe','Europe','Europe','Africa','Africa','Africa'],
         ['Population','GDP','Gini','Population','GDP','Gini','Population','GDP','Gini'],
         [2010,2011,2012,2010,2011,2012,2010,2011,2012]]
data = np.random.randint(0,10,27).reshape(9,3)
cols = ['UN','World Bank','IMF']

# %%
df = pd.DataFrame(data=data,index=index,columns=cols)

# %%
df
# Out:
#                         UN  World Bank  IMF
# Asia   Population 2010   6           9    7
#        GDP        2011   5           1    8
#        Gini       2012   1           0    3
# Europe Population 2010   8           0    4
#        GDP        2011   8           1    8
#        Gini       2012   4           2    7
# Africa Population 2010   7           2    4
#        GDP        2011   1           7    2
#        Gini       2012   9           3    3

# %%
df.index.names
# Out:
# FrozenList([None, None, None])

# %%
df.index.names = ['Region','Parameter','Year']

# %%
df
# Out:
#                         UN  World Bank  IMF
# Region Parameter  Year
# Asia   Population 2010   6           9    7
#        GDP        2011   5           1    8
#        Gini       2012   1           0    3
# Europe Population 2010   8           0    4
#        GDP        2011   8           1    8
#        Gini       2012   4           2    7
# Africa Population 2010   7           2    4
#        GDP        2011   1           7    2
#        Gini       2012   9           3    3

# %%
df.loc['Asia'].loc[['GDP','Gini'],['UN','World Bank']]
# Out:
#                 UN  World Bank
# Parameter Year
# GDP       2011   5           1
# Gini      2012   1           0

# %%
df['UN']
# Out:
# Region  Parameter   Year
# Asia    Population  2010    6
#         GDP         2011    5
#         Gini        2012    1
# Europe  Population  2010    8
#         GDP         2011    8
#         Gini        2012    4
# Africa  Population  2010    7
#         GDP         2011    1
#         Gini        2012    9
# Name: UN, dtype: int32

# %%
df.xs(('Asia','GDP'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2895: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
#       UN  World Bank  IMF
# Year
# 2011   5           1    8

# %%
df.xs(key=('GDP',2011),level=['Parameter','Year'])
# Out:
#         UN  World Bank  IMF
# Region
# Asia     5           1    8
# Europe   8           1    8
# Africa   1           7    2

# %% [markdown]
# ## Handling missing data

# %%
## Creating a dataframe with a dictionary
df = pd.DataFrame({'India':[0,np.nan,2,3,4], 'China':[10,np.nan,12,13,np.nan], 'US':[np.nan,np.nan,np.nan,np.nan,np.nan],'Canada':[20,21,22,23,24]})

# %%
df
# Out:
#    India  China  US  Canada
# 0    0.0   10.0 NaN      20
# 1    NaN    NaN NaN      21
# 2    2.0   12.0 NaN      22
# 3    3.0   13.0 NaN      23
# 4    4.0    NaN NaN      24

# %%
df.isnull()
# Out:
#    India  China    US  Canada
# 0  False  False  True   False
# 1   True   True  True   False
# 2  False  False  True   False
# 3  False  False  True   False
# 4  False   True  True   False

# %%
df.notnull()
# Out:
#    India  China     US  Canada
# 0   True   True  False    True
# 1  False  False  False    True
# 2   True   True  False    True
# 3   True   True  False    True
# 4   True  False  False    True

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [India, China, US, Canada]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#    Canada
# 0      20
# 1      21
# 2      22
# 3      23
# 4      24

# %%
df.dropna(thresh=2)
# Out:
#    India  China  US  Canada
# 0    0.0   10.0 NaN      20
# 2    2.0   12.0 NaN      22
# 3    3.0   13.0 NaN      23
# 4    4.0    NaN NaN      24

# %%
df.fillna(20)
# Out:
#    India  China    US  Canada
# 0    0.0   10.0  20.0      20
# 1   20.0   20.0  20.0      21
# 2    2.0   12.0  20.0      22
# 3    3.0   13.0  20.0      23
# 4    4.0   20.0  20.0      24

# %%
df.fillna(method='ffill')
# Out:
#    India  China  US  Canada
# 0    0.0   10.0 NaN      20
# 1    0.0   10.0 NaN      21
# 2    2.0   12.0 NaN      22
# 3    3.0   13.0 NaN      23
# 4    4.0   13.0 NaN      24

# %%
df.fillna(method='bfill')
# Out:
#    India  China  US  Canada
# 0    0.0   10.0 NaN      20
# 1    2.0   12.0 NaN      21
# 2    2.0   12.0 NaN      22
# 3    3.0   13.0 NaN      23
# 4    4.0    NaN NaN      24

# %%
df.fillna(method='pad')
# Out:
#    India  China  US  Canada
# 0    0.0   10.0 NaN      20
# 1    0.0   10.0 NaN      21
# 2    2.0   12.0 NaN      22
# 3    3.0   13.0 NaN      23
# 4    4.0   13.0 NaN      24

# %% [markdown]
# ## Merging and Concatenating

# %% [markdown]
# ### Merging

# %%
df1 = pd.DataFrame({'key':'a b c d e'.split(), 'X1':[1,2,3,4,5], 'X2':range(6,11)})
df2 = pd.DataFrame({'key':'a b c f g'.split(), 'X1':[1,2,3,11,12], 'X2':range(4,9)})

# %%
df1
# Out:
#   key  X1  X2
# 0   a   1   6
# 1   b   2   7
# 2   c   3   8
# 3   d   4   9
# 4   e   5  10

# %%
df2
# Out:
#   key  X1  X2
# 0   a   1   4
# 1   b   2   5
# 2   c   3   6
# 3   f  11   7
# 4   g  12   8

# %%
pd.merge(df1,df2,how='inner',on='key')
# Out:
#   key  X1_x  X2_x  X1_y  X2_y
# 0   a     1     6     1     4
# 1   b     2     7     2     5
# 2   c     3     8     3     6

# %%
pd.merge(df1,df2,how='left',on='key')
# Out:
#   key  X1_x  X2_x  X1_y  X2_y
# 0   a     1     6   1.0   4.0
# 1   b     2     7   2.0   5.0
# 2   c     3     8   3.0   6.0
# 3   d     4     9   NaN   NaN
# 4   e     5    10   NaN   NaN

# %%
pd.merge(df1,df2,how='right',on='key')
# Out:
#   key  X1_x  X2_x  X1_y  X2_y
# 0   a   1.0   6.0     1     4
# 1   b   2.0   7.0     2     5
# 2   c   3.0   8.0     3     6
# 3   f   NaN   NaN    11     7
# 4   g   NaN   NaN    12     8

# %%
pd.merge(df1,df2,how='outer',on='key')
# Out:
#   key  X1_x  X2_x  X1_y  X2_y
# 0   a   1.0   6.0   1.0   4.0
# 1   b   2.0   7.0   2.0   5.0
# 2   c   3.0   8.0   3.0   6.0
# 3   d   4.0   9.0   NaN   NaN
# 4   e   5.0  10.0   NaN   NaN
# 5   f   NaN   NaN  11.0   7.0
# 6   g   NaN   NaN  12.0   8.0

# %%
left = pd.DataFrame({'key1': ['a', 'a', 'b', 'c'],
                     'key2': ['a', 'b', 'a', 'b'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['a', 'b', 'b', 'c'],
                      'key2': ['a', 'b', 'a', 'a'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0    a    a  A0  B0  C0  D0
# 1    b    a  A2  B2  C2  D2

# %%
pd.merge(left,right,how='right',on=['key1','key2'])
# Out:
#   key1 key2    A    B   C   D
# 0    a    a   A0   B0  C0  D0
# 1    b    a   A2   B2  C2  D2
# 2    b    b  NaN  NaN  C1  D1
# 3    c    a  NaN  NaN  C3  D3

# %%
pd.merge(left,right,how='left',on=['key1','key2'])
# Out:
#   key1 key2   A   B    C    D
# 0    a    a  A0  B0   C0   D0
# 1    a    b  A1  B1  NaN  NaN
# 2    b    a  A2  B2   C2   D2
# 3    c    b  A3  B3  NaN  NaN

# %%
pd.merge(left,right,how='outer',on=['key1','key2'])
# Out:
#   key1 key2    A    B    C    D
# 0    a    a   A0   B0   C0   D0
# 1    a    b   A1   B1  NaN  NaN
# 2    b    a   A2   B2   C2   D2
# 3    c    b   A3   B3  NaN  NaN
# 4    b    b  NaN  NaN   C1   D1
# 5    c    a  NaN  NaN   C3   D3

# %% [markdown]
# ### Concatenation

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4,5,6,7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
