# %% [markdown]
# ## Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### You can create a series object with a list or numpy array or a dictionary

# %% [markdown]
# ### Series with List

# %%
my_list = [i for i in range(0,5)]
my_index =[i for i in 'risha']

# %%
my_list, my_index
# Out:
# ([0, 1, 2, 3, 4], ['r', 'i', 's', 'h', 'a'])

# %%
pd.Series(data=my_list, index=my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int64

# %%
pd.Series(my_list)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
pd.Series(my_list,my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int64

# %% [markdown]
# ### Series with NumPy array

# %%
array = np.arange(0,5)

# %%
array, my_index
# Out:
# (array([0, 1, 2, 3, 4]), ['r', 'i', 's', 'h', 'a'])

# %%
pd.Series(data = array)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32

# %%
pd.Series(data = array, index = my_index)
# Out:
# r    0
# i    1
# s    2
# h    3
# a    4
# dtype: int32

# %% [markdown]
# ### Series with Dictionary

# %%
dict1 = {'one':1,'two':2,'three':3,'four':4}

# %%
dict1
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
ser1 = pd.Series(dict1)
ser1
# Out:
# one      1
# two      2
# three    3
# four     4
# dtype: int64

# %% [markdown]
# ## Series can hold wide variety of datatypes

# %%
## strings
list1 = ['a','b','c','d']
list2 = [1,2,3,4]
ser2 = pd.Series(data= list1 , index= list2)
ser2
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
## holding functions
list1 = [sum,min,max,type,range]
list2 = ['sum','min','max','type','range']
ser3 = pd.Series(data=list1, index=list2)
ser3
# Out:
# sum      <built-in function sum>
# min      <built-in function min>
# max      <built-in function max>
# type              <class 'type'>
# range            <class 'range'>
# dtype: object

# %% [markdown]
# ## Grabbing data from series

# %%
ser2[1]
# Out:
# 'a'

# %%
dict1 = {'Mumbai':100,'Delhi':200,'Kolkata':300,'Chennai':400,'Bengaluru':500}
ser1 = pd.Series(dict1)
ser2 = pd.Series({'Mumbai':100,'Kolkata':300,'Chennai':400,'Bengaluru':500})
ser3 = pd.Series({'Mumbai':100,'Delhi':200,'Kolkata':300,'Bengaluru':500})

# %%
ser1['Mumbai']
# Out:
# 100

# %%
ser1
# Out:
# Mumbai       100
# Delhi        200
# Kolkata      300
# Chennai      400
# Bengaluru    500
# dtype: int64

# %%
ser2
# Out:
# Mumbai       100
# Kolkata      300
# Chennai      400
# Bengaluru    500
# dtype: int64

# %%
ser3
# Out:
# Mumbai       100
# Delhi        200
# Kolkata      300
# Bengaluru    500
# dtype: int64

# %% [markdown]
# ### Basic operations on Series

# %%
ser1 +  ser2
# Out:
# Bengaluru    1000.0
# Chennai       800.0
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %%
ser2 + ser3
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %% [markdown]
# ## Basic functions and attributes

# %%
ser = ser2 + ser3
ser
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# Delhi           NaN
# Kolkata       600.0
# Mumbai        200.0
# dtype: float64

# %%
ser.isnull()
# Out:
# Bengaluru    False
# Chennai       True
# Delhi         True
# Kolkata      False
# Mumbai       False
# dtype: bool

# %%
ser.notnull()
# Out:
# Bengaluru     True
# Chennai      False
# Delhi        False
# Kolkata       True
# Mumbai        True
# dtype: bool

# %%
ser.size
# Out:
# 5

# %%
ser.axes
# Out:
# [Index(['Bengaluru', 'Chennai', 'Delhi', 'Kolkata', 'Mumbai'], dtype='object')]

# %%
ser.values
# Out:
# array([1000.,   nan,   nan,  600.,  200.])

# %%
ser.empty
# Out:
# False

# %%
ser.max()
# Out:
# 1000.0

# %%
ser.min()
# Out:
# 200.0

# %%
ser.std()
# Out:
# 400.0

# %%
ser.var()
# Out:
# 160000.0

# %%
ser.sum()
# Out:
# 1800.0

# %%
ser.mean()
# Out:
# 600.0

# %%
ser.head(2)
# Out:
# Bengaluru    1000.0
# Chennai         NaN
# dtype: float64

# %%
ser.tail(3)
# Out:
# Delhi        NaN
# Kolkata    600.0
# Mumbai     200.0
# dtype: float64

# %% [markdown]
# ## Dataframes

# %% [markdown]
# ### Creating a dataframe

# %%
rows = 'India Australia Japan US Russia England France Germany Bhutan Fiji'.split()
cols = 'c1 c2 c3 c4 c5 c6 c7 c8 c9 c10'.split()
data = np.random.randint(0,100,100).reshape(10,10)

# %%
rows
# Out:
# ['India',
#  'Australia',
#  'Japan',
#  'US',
#  'Russia',
#  'England',
#  'France',
#  'Germany',
#  'Bhutan',
#  'Fiji']

# %%
cols
# Out:
# ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10']

# %%
data
# Out:
# array([[89,  4, 64, 21, 81, 76,  0, 89, 65, 19],
#        [61,  9, 85, 89, 55, 16, 41, 20, 92, 66],
#        [89, 82, 72, 68, 58, 53, 83, 54, 60, 77],
#        [60, 44, 10, 99, 99, 64, 23, 67,  2, 30],
#        [13, 39, 99, 82, 81, 57, 50, 52, 75,  8],
#        [87, 50, 21, 60, 24, 21, 87, 70,  4, 20],
#        [70, 15, 64, 53, 41, 39, 65, 97, 64, 31],
#        [98, 42, 99, 53, 90, 74, 87, 33, 22, 11],
#        [88, 87, 49, 62, 65, 48, 45, 86, 63,  2],
#        [94, 48, 67, 84, 39,  4, 63, 84, 11, 40]])

# %%
df = pd.DataFrame(data=data, index=rows, columns=cols)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      89   4  64  21  81  76   0  89  65   19
# Australia  61   9  85  89  55  16  41  20  92   66
# Japan      89  82  72  68  58  53  83  54  60   77
# US         60  44  10  99  99  64  23  67   2   30
# Russia     13  39  99  82  81  57  50  52  75    8
# England    87  50  21  60  24  21  87  70   4   20
# France     70  15  64  53  41  39  65  97  64   31
# Germany    98  42  99  53  90  74  87  33  22   11
# Bhutan     88  87  49  62  65  48  45  86  63    2
# Fiji       94  48  67  84  39   4  63  84  11   40

# %% [markdown]
#  ## Getting data out of DataFrames

# %% [markdown]
# ### Selecting columns

# %%
df['c1']
# Out:
# India        89
# Australia    61
# Japan        89
# US           60
# Russia       13
# England      87
# France       70
# Germany      98
# Bhutan       88
# Fiji         94
# Name: c1, dtype: int32

# %%
df[['c1','c2']]
# Out:
#            c1  c2
# India      89   4
# Australia  61   9
# Japan      89  82
# US         60  44
# Russia     13  39
# England    87  50
# France     70  15
# Germany    98  42
# Bhutan     88  87
# Fiji       94  48

# %% [markdown]
# ### Selecting rows

# %%
df.loc['India']
# Out:
# c1     89
# c2      4
# c3     64
# c4     21
# c5     81
# c6     76
# c7      0
# c8     89
# c9     65
# c10    19
# Name: India, dtype: int32

# %%
df.iloc[3]
# Out:
# c1     60
# c2     44
# c3     10
# c4     99
# c5     99
# c6     64
# c7     23
# c8     67
# c9      2
# c10    30
# Name: US, dtype: int32

# %%
df.loc[['India','England','Russia']]
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India    89   4  64  21  81  76   0  89  65   19
# England  87  50  21  60  24  21  87  70   4   20
# Russia   13  39  99  82  81  57  50  52  75    8

# %% [markdown]
# ### Selecting subset of a dataframe

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      89   4  64  21  81  76   0  89  65   19
# Australia  61   9  85  89  55  16  41  20  92   66
# Japan      89  82  72  68  58  53  83  54  60   77
# US         60  44  10  99  99  64  23  67   2   30
# Russia     13  39  99  82  81  57  50  52  75    8
# England    87  50  21  60  24  21  87  70   4   20
# France     70  15  64  53  41  39  65  97  64   31
# Germany    98  42  99  53  90  74  87  33  22   11
# Bhutan     88  87  49  62  65  48  45  86  63    2
# Fiji       94  48  67  84  39   4  63  84  11   40

# %%
df.loc[['Japan','US','Russia'],['c5','c6','c7']]
# Out:
#         c5  c6  c7
# Japan   58  53  83
# US      99  64  23
# Russia  81  57  50

# %% [markdown]
# ### Adding a new column

# %%
df['c11'] = np.arange(0,10)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      89   4  64  21  81  76   0  89  65   19    0
# Australia  61   9  85  89  55  16  41  20  92   66    1
# Japan      89  82  72  68  58  53  83  54  60   77    2
# US         60  44  10  99  99  64  23  67   2   30    3
# Russia     13  39  99  82  81  57  50  52  75    8    4
# England    87  50  21  60  24  21  87  70   4   20    5
# France     70  15  64  53  41  39  65  97  64   31    6
# Germany    98  42  99  53  90  74  87  33  22   11    7
# Bhutan     88  87  49  62  65  48  45  86  63    2    8
# Fiji       94  48  67  84  39   4  63  84  11   40    9

# %% [markdown]
# ### Adding a new row

# %%
df.loc['Poland'] = np.random.randint(0,100,11)

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      89   4  64  21  81  76   0  89  65   19    0
# Australia  61   9  85  89  55  16  41  20  92   66    1
# Japan      89  82  72  68  58  53  83  54  60   77    2
# US         60  44  10  99  99  64  23  67   2   30    3
# Russia     13  39  99  82  81  57  50  52  75    8    4
# England    87  50  21  60  24  21  87  70   4   20    5
# France     70  15  64  53  41  39  65  97  64   31    6
# Germany    98  42  99  53  90  74  87  33  22   11    7
# Bhutan     88  87  49  62  65  48  45  86  63    2    8
# Fiji       94  48  67  84  39   4  63  84  11   40    9
# Poland     42  98  55  87  48  89   1  19  35   14   57

# %% [markdown]
# ### Dropping a column

# %%
df.drop('c11', axis=1)
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10
# India      89   4  64  21  81  76   0  89  65   19
# Australia  61   9  85  89  55  16  41  20  92   66
# Japan      89  82  72  68  58  53  83  54  60   77
# US         60  44  10  99  99  64  23  67   2   30
# Russia     13  39  99  82  81  57  50  52  75    8
# England    87  50  21  60  24  21  87  70   4   20
# France     70  15  64  53  41  39  65  97  64   31
# Germany    98  42  99  53  90  74  87  33  22   11
# Bhutan     88  87  49  62  65  48  45  86  63    2
# Fiji       94  48  67  84  39   4  63  84  11   40
# Poland     42  98  55  87  48  89   1  19  35   14

# %% [markdown]
# ### Dropping a row

# %%
df.drop('Poland',axis=0)
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      89   4  64  21  81  76   0  89  65   19    0
# Australia  61   9  85  89  55  16  41  20  92   66    1
# Japan      89  82  72  68  58  53  83  54  60   77    2
# US         60  44  10  99  99  64  23  67   2   30    3
# Russia     13  39  99  82  81  57  50  52  75    8    4
# England    87  50  21  60  24  21  87  70   4   20    5
# France     70  15  64  53  41  39  65  97  64   31    6
# Germany    98  42  99  53  90  74  87  33  22   11    7
# Bhutan     88  87  49  62  65  48  45  86  63    2    8
# Fiji       94  48  67  84  39   4  63  84  11   40    9

# %% [markdown]
# ## Conditional Selection

# %%
df >=50
# Out:
#               c1     c2     c3     c4     c5     c6     c7     c8     c9  \
# India       True  False   True  False   True   True  False   True   True
# Australia   True  False   True   True   True  False  False  False   True
# Japan       True   True   True   True   True   True   True   True   True
# US          True  False  False   True   True   True  False   True  False
# Russia     False  False   True   True   True   True   True   True   True
# England     True   True  False   True  False  False   True   True  False
# France      True  False   True   True  False  False   True   True   True
# Germany     True  False   True   True   True   True   True  False  False
# Bhutan      True   True  False   True   True  False  False   True   True
# Fiji        True  False   True   True  False  False   True   True  False
# Poland     False   True   True   True  False   True  False  False  False
#
#              c10    c11
# India      False  False
# Australia   True  False
# Japan       True  False
# US         False  False
# Russia     False  False
# England    False  False
# France     False  False
# Germany    False  False
# Bhutan     False  False
# Fiji       False  False
# Poland     False   True

# %%
df[df>=50]
# Out:
#              c1    c2    c3    c4    c5    c6    c7    c8    c9   c10   c11
# India      89.0   NaN  64.0   NaN  81.0  76.0   NaN  89.0  65.0   NaN   NaN
# Australia  61.0   NaN  85.0  89.0  55.0   NaN   NaN   NaN  92.0  66.0   NaN
# Japan      89.0  82.0  72.0  68.0  58.0  53.0  83.0  54.0  60.0  77.0   NaN
# US         60.0   NaN   NaN  99.0  99.0  64.0   NaN  67.0   NaN   NaN   NaN
# Russia      NaN   NaN  99.0  82.0  81.0  57.0  50.0  52.0  75.0   NaN   NaN
# England    87.0  50.0   NaN  60.0   NaN   NaN  87.0  70.0   NaN   NaN   NaN
# France     70.0   NaN  64.0  53.0   NaN   NaN  65.0  97.0  64.0   NaN   NaN
# Germany    98.0   NaN  99.0  53.0  90.0  74.0  87.0   NaN   NaN   NaN   NaN
# Bhutan     88.0  87.0   NaN  62.0  65.0   NaN   NaN  86.0  63.0   NaN   NaN
# Fiji       94.0   NaN  67.0  84.0   NaN   NaN  63.0  84.0   NaN   NaN   NaN
# Poland      NaN  98.0  55.0  87.0   NaN  89.0   NaN   NaN   NaN   NaN  57.0

# %%
df[df['c1']>=50]
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India      89   4  64  21  81  76   0  89  65   19    0
# Australia  61   9  85  89  55  16  41  20  92   66    1
# Japan      89  82  72  68  58  53  83  54  60   77    2
# US         60  44  10  99  99  64  23  67   2   30    3
# England    87  50  21  60  24  21  87  70   4   20    5
# France     70  15  64  53  41  39  65  97  64   31    6
# Germany    98  42  99  53  90  74  87  33  22   11    7
# Bhutan     88  87  49  62  65  48  45  86  63    2    8
# Fiji       94  48  67  84  39   4  63  84  11   40    9

# %%
df[df['c1']>=50].loc[['India','Bhutan']]
# Out:
#         c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# India   89   4  64  21  81  76   0  89  65   19    0
# Bhutan  88  87  49  62  65  48  45  86  63    2    8

# %%
 df[(df>50) | (df%20==0)]
# Out:
#              c1    c2    c3    c4    c5    c6    c7    c8    c9   c10   c11
# India      89.0   NaN  64.0   NaN  81.0  76.0   0.0  89.0  65.0   NaN   0.0
# Australia  61.0   NaN  85.0  89.0  55.0   NaN   NaN  20.0  92.0  66.0   NaN
# Japan      89.0  82.0  72.0  68.0  58.0  53.0  83.0  54.0  60.0  77.0   NaN
# US         60.0   NaN   NaN  99.0  99.0  64.0   NaN  67.0   NaN   NaN   NaN
# Russia      NaN   NaN  99.0  82.0  81.0  57.0   NaN  52.0  75.0   NaN   NaN
# England    87.0   NaN   NaN  60.0   NaN   NaN  87.0  70.0   NaN  20.0   NaN
# France     70.0   NaN  64.0  53.0   NaN   NaN  65.0  97.0  64.0   NaN   NaN
# Germany    98.0   NaN  99.0  53.0  90.0  74.0  87.0   NaN   NaN   NaN   NaN
# Bhutan     88.0  87.0   NaN  62.0  65.0   NaN   NaN  86.0  63.0   NaN   NaN
# Fiji       94.0   NaN  67.0  84.0   NaN   NaN  63.0  84.0   NaN  40.0   NaN
# Poland      NaN  98.0  55.0  87.0   NaN  89.0   NaN   NaN   NaN   NaN  57.0

# %% [markdown]
# ### Useful Methods

# %%
### RESET INDEX
df.reset_index()
# Out:
#         index  c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# 0       India  89   4  64  21  81  76   0  89  65   19    0
# 1   Australia  61   9  85  89  55  16  41  20  92   66    1
# 2       Japan  89  82  72  68  58  53  83  54  60   77    2
# 3          US  60  44  10  99  99  64  23  67   2   30    3
# 4      Russia  13  39  99  82  81  57  50  52  75    8    4
# 5     England  87  50  21  60  24  21  87  70   4   20    5
# 6      France  70  15  64  53  41  39  65  97  64   31    6
# 7     Germany  98  42  99  53  90  74  87  33  22   11    7
# 8      Bhutan  88  87  49  62  65  48  45  86  63    2    8
# 9        Fiji  94  48  67  84  39   4  63  84  11   40    9
# 10     Poland  42  98  55  87  48  89   1  19  35   14   57

# %%
df['new_ind'] = 'a b c d e f g h i j k'.split()

# %%
df
# Out:
#            c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11 new_ind
# India      89   4  64  21  81  76   0  89  65   19    0       a
# Australia  61   9  85  89  55  16  41  20  92   66    1       b
# Japan      89  82  72  68  58  53  83  54  60   77    2       c
# US         60  44  10  99  99  64  23  67   2   30    3       d
# Russia     13  39  99  82  81  57  50  52  75    8    4       e
# England    87  50  21  60  24  21  87  70   4   20    5       f
# France     70  15  64  53  41  39  65  97  64   31    6       g
# Germany    98  42  99  53  90  74  87  33  22   11    7       h
# Bhutan     88  87  49  62  65  48  45  86  63    2    8       i
# Fiji       94  48  67  84  39   4  63  84  11   40    9       j
# Poland     42  98  55  87  48  89   1  19  35   14   57       k

# %%
df.set_index('new_ind',inplace=True)

# %%
df
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# a        89   4  64  21  81  76   0  89  65   19    0
# b        61   9  85  89  55  16  41  20  92   66    1
# c        89  82  72  68  58  53  83  54  60   77    2
# d        60  44  10  99  99  64  23  67   2   30    3
# e        13  39  99  82  81  57  50  52  75    8    4
# f        87  50  21  60  24  21  87  70   4   20    5
# g        70  15  64  53  41  39  65  97  64   31    6
# h        98  42  99  53  90  74  87  33  22   11    7
# i        88  87  49  62  65  48  45  86  63    2    8
# j        94  48  67  84  39   4  63  84  11   40    9
# k        42  98  55  87  48  89   1  19  35   14   57

# %%
df.head()
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# a        89   4  64  21  81  76   0  89  65   19    0
# b        61   9  85  89  55  16  41  20  92   66    1
# c        89  82  72  68  58  53  83  54  60   77    2
# d        60  44  10  99  99  64  23  67   2   30    3
# e        13  39  99  82  81  57  50  52  75    8    4

# %%
df.tail()
# Out:
#          c1  c2  c3  c4  c5  c6  c7  c8  c9  c10  c11
# new_ind
# g        70  15  64  53  41  39  65  97  64   31    6
# h        98  42  99  53  90  74  87  33  22   11    7
# i        88  87  49  62  65  48  45  86  63    2    8
# j        94  48  67  84  39   4  63  84  11   40    9
# k        42  98  55  87  48  89   1  19  35   14   57

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, a to k
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      11 non-null     int32
#  1   c2      11 non-null     int32
#  2   c3      11 non-null     int32
#  3   c4      11 non-null     int32
#  4   c5      11 non-null     int32
#  5   c6      11 non-null     int32
#  6   c7      11 non-null     int32
#  7   c8      11 non-null     int32
#  8   c9      11 non-null     int32
#  9   c10     11 non-null     int32
#  10  c11     11 non-null     int32
# dtypes: int32(11)
# memory usage: 572.0+ bytes

# %%
df.describe()
# Out:
#               c1         c2         c3         c4         c5         c6  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   71.909091  47.090909  62.272727  68.909091  61.909091  49.181818
# std    26.208604  31.386158  28.288128  22.282076  23.577339  26.940001
# min    13.000000   4.000000  10.000000  21.000000  24.000000   4.000000
# 25%    60.500000  27.000000  52.000000  56.500000  44.500000  30.000000
# 50%    87.000000  44.000000  64.000000  68.000000  58.000000  53.000000
# 75%    89.000000  66.000000  78.500000  85.500000  81.000000  69.000000
# max    98.000000  98.000000  99.000000  99.000000  99.000000  89.000000
#
#               c7         c8         c9        c10        c11
# count  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   49.545455  61.000000  44.818182  28.909091   9.272727
# std    31.551113  27.766887  31.198776  23.872388  16.087827
# min     0.000000  19.000000   2.000000   2.000000   0.000000
# 25%    32.000000  42.500000  16.500000  12.500000   2.500000
# 50%    50.000000  67.000000  60.000000  20.000000   5.000000
# 75%    74.000000  85.000000  64.500000  35.500000   7.500000
# max    87.000000  97.000000  92.000000  77.000000  57.000000
